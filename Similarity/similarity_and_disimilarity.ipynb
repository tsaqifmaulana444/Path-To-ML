# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Teknik Similarity
# - Euclidian Distance
# - Manhattan Distance
# - Chebyshev Distance
# - Cosine Similarity

# %% [markdown]
# ![image.png](attachment:image.png)
