# %% [markdown]
# ### Teknik teknik dalam klasifikasi data
# - Probabilitas
# - If Then
# - Garis Keputusan
# - Statistik Average Distance
# - Pengaruh Jumlah Data Tetangga
# - Titik Pusat Kelas
# - Jarak Terdekat Dengan Jarak Tetangga

# %% [markdown]
# ### Perbedaaan Poin 5 Dan 7
#
# Didalam poin 5 data yang diambil akan berdasarkan nilai k (tetangga), paramter data yang diambil hanya berdasarkan jarak dekatnya data dengan target data
#
# Sedangkan di dalam poin 7 data akan diambil berdasarkan nilai k, tetapi data-data yang diambil akan berdasakran jumlah kategori yang tersedia, data akan diambil adalah data yang dekat dengan data target
#
# ![image.png](attachment:image.png)
