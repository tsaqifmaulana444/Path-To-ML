# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Didalam information gain, atribut dengan nilai yang paling tinggi adalah atribut yang akan dijadikan root
#
# Sedangkan didalam gini index, atribut dengan nilai yang paling rendah adalah atribut yang akan dijadikan root
